# %%
#importing the required libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
#Reading the csv file
data=pd.read_csv('MergeFileCrop.csv.txt')
data['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
data.isnull().any()
# Out:
# Unnamed: 0     False
# temperature    False
# humidity       False
# ph             False
# rainfall       False
# label          False
# dtype: bool

# %%
data= data.drop('Unnamed: 0',axis=1)

# %%
data = data.sample(frac = 1)  
print(data.head(1))
# Out:
#       temperature  humidity        ph   rainfall   label
# 1268    29.672291  83.71499  5.891196  66.484904  grapes

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
data["label"] = le.fit_transform(data["label"])
data['label'].unique()
# Out:
# array([ 7,  3, 21,  9,  0,  2, 15, 14,  8,  4,  6,  1, 18, 19, 17, 11, 20,
#        12, 10,  5, 13, 16], dtype=int64)

# %%
data.head(2200)
# Out:
#       temperature   humidity        ph    rainfall  label
# 1268    29.672291  83.714990  5.891196   66.484904      7
# 203     18.868056  15.658092  6.391174   88.510490      3
# 1303    24.746313  88.308663  6.581588   57.958261     21
# 365     18.810973  21.278330  5.889615  125.084915      9
# 1504    23.410447  91.699133  5.587906  116.077793      0
# 759     31.521047  66.557237  7.580527   61.711114      2
# 1450    27.465836  94.876790  6.440585   27.278998     15
# 641     29.830404  89.304283  6.324005   58.866871     14
# 615     29.784167  85.169070  6.793856   40.778728     14
# 1292    27.920049  82.932624  5.733540   69.920928      7
# 2056    26.567673  80.904245  6.352771  181.291561      8
# 1808    26.585804  90.986176  5.558807  178.811608      4
# 1921    25.668914  81.381033  6.652144   78.595958      6
# 1028    26.398551  81.360289  5.571401   98.167520      1
# 408     29.385386  63.477420  5.761703   90.054227     18
# 978     24.839544  86.887381  6.034613  107.643577     19
# 1520    21.072734  93.565860  6.041054  107.873701      0
# 1735    34.280461  90.555616  6.825371   98.540477     17
# 144     22.217382  72.854628  6.801639  106.621316     11
# 34      25.735429  83.882662  6.149411  233.132137     20
# 1322    25.794489  84.268307  6.762472   56.452292     21
# 1732    40.769987  92.092786  6.747976  209.867841     17
# 117     25.142061  65.261851  6.021902   76.684560     11
# 1370    26.260287  86.145859  6.769894   58.978788     21
# 2055    25.848795  87.816617  7.333143  152.619440      8
# 454     24.807102  45.011100  5.023115  188.492864     18
# 60      20.414470  82.208026  7.592491  245.151130     20
# 1141    30.914715  49.929639  6.810186   90.140478     12
# 250     19.407517  18.980305  7.806748   80.250646      3
# 628     28.689985  87.504368  6.769416   44.565984     14
# ...           ...        ...       ...         ...    ...
# 230     20.566019  14.258040  6.654425   83.759371      3
# 1894    26.446001  98.299378  6.008386  221.225817      4
# 145     20.583140  69.001286  6.499936   66.293904     11
# 761     29.384003  64.149285  7.358975   65.241944      2
# 127     21.535741  71.509060  5.918264  102.485293     11
# 1714    36.322681  93.061344  6.989927  141.173693     17
# 312     19.622078  18.671709  5.809420  144.156745      9
# 2093    26.985822  89.055879  7.432768  193.877871      8
# 504     27.780315  54.650300  8.153023   32.050253     13
# 1359    24.889105  85.870591  6.110143   51.706991     21
# 1602    13.360506  91.356082  7.335158  111.226688     16
# 481     23.174096  36.678471  6.962386  162.593126     18
# 389     19.306073  23.963628  5.591561  129.344933      9
# 128     23.089749  63.104596  5.588651   70.434736     11
# 297     18.897802  19.761829  7.452671   69.095125      3
# 1919    25.992374  77.054355  7.368258   89.118821      6
# 544     26.457078  56.402263  5.993514   64.161677     13
# 208     18.179123  18.904269  7.010571   81.849975      3
# 1663    13.703192  90.955894  7.609348  106.294488     16
# 1961    22.426733  81.534808  6.745104   65.544758      6
# 381     23.897568  22.743790  5.940547  112.661643      9
# 315     20.611622  24.363141  5.792745   69.638339      9
# 1345    24.677416  82.754114  6.206247   57.057094     21
# 303     16.433403  24.240459  5.926677  140.371781      9
# 756     29.578127  66.175877  7.497469   69.438955      2
# 1262    40.660123  81.249960  6.372960   74.030301      7
# 384     24.163844  19.279078  5.827380  116.732432      9
# 869     27.704968  63.209150  7.746724   37.461607     10
# 218     17.480426  15.755940  7.228963   66.969806      3
# 723     30.415885  67.663238  6.744412   63.024732      2
#
# [2200 rows x 5 columns]

# %%
import seaborn as sns
sns.heatmap(data.corr())

# %%
x = data.iloc[:,0:4].values
y = data.iloc[:,4:].values

# %%
x.shape
# Out:
# (2200, 4)

# %%
x
# Out:
# array([[29.67229086, 83.71498986,  5.89119565, 66.48490371],
#        [18.86805647, 15.65809214,  6.39117359, 88.51048983],
#        [24.74631269, 88.30866319,  6.58158793, 57.95826144],
#        ...,
#        [27.70496805, 63.20915034,  7.74672376, 37.46160727],
#        [17.48042641, 15.7559405 ,  7.22896345, 66.96980581],
#        [30.41588462, 67.66323804,  6.74441168, 63.02473185]])

# %%
y
# Out:
# array([[ 7],
#        [ 3],
#        [21],
#        ...,
#        [10],
#        [ 3],
#        [ 2]])

# %%
y.shape
# Out:
# (2200, 1)

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest, Ytrain, Ytest = train_test_split(x,y,test_size = 0.2,random_state =2)

# %%
# RABDOM FOREST 
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn import tree
acc=[]
model=[]
regressor = RandomForestClassifier(n_estimators=20, random_state=0)
regressor.fit(Xtrain,Ytrain)

predicted_values = regressor.predict(Xtest)

x = metrics.accuracy_score(Ytest, predicted_values)
acc.append(x)
model.append('RF')
print("RF's Accuracy is: ", x)

print(classification_report(Ytest,predicted_values))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ae198f0c7f2d> in <module>
#       7 model=[]
#       8 regressor = RandomForestClassifier(n_estimators=20, random_state=0)
# ----> 9 regressor.fit(Xtrain,Ytrain)
#      10
#      11 predicted_values = regressor.predict(Xtest)
#
# NameError: name 'Xtrain' is not defined

# %%
# NAVIE_BAYES
from sklearn.naive_bayes import GaussianNB

NaiveBayes = GaussianNB()

NaiveBayes.fit(Xtrain,Ytrain)
acc1 =[]
model1 =[]
predicted_values1 = NaiveBayes.predict(Xtest)
x1= metrics.accuracy_score(Ytest, predicted_values1)
acc1.append(x1)
model1.append('Naive Bayes')
print("Naive Bayes's Accuracy is: ", x1)

print(classification_report(Ytest,predicted_values1))

# %%
index = ['mungbean','pomegranate','pigeonpeas','chickpea','papaya','lentil','cotton', 'jute','grapes',
'coffee','apple','maize', 'coconut',  'banana','mango','blackgram','orange', 'rice','watermelon',
'mothbeans','kidneybeans']

# %%
y_p = regressor.predict(np.array([[20.27774362,82.89408619,5.718627177999999,241.97419490000001]]))
y_list = (y_p.flatten('F'))
import pandas as pd
pd.set_option('display.max_columns', 34)
print(data[:9])
y_list = int(y_list)
print("----------------------------------")
print(y_list)
print("the suitable crop is",index[y_list])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-152fe957d4fc> in <module>
# ----> 1 y_p = regressor.predict(np.array([[20.27774362,82.89408619,5.718627177999999,241.97419490000001]]))
#       2 y_list = (y_p.flatten('F'))
#       3 import pandas as pd
#       4 pd.set_option('display.max_columns', 34)
#       5 print(data[:9])
#
# NameError: name 'regressor' is not defined

# %%
y_p1 = NaiveBayes.predict(np.array([[27.33684386,88.50229102,7.033012777000001,51.09802625]]))
y_list1 = (y_p1.flatten('F'))
import pandas as pd
pd.set_option('display.max_columns', 34)
print(data[:9])
y_list1 = int(y_list1)
print("----------------------------------")
print(y_list1)
#print("the suitable crop is",index[y_list1])
# Out:
#       temperature   humidity        ph    rainfall  label
# 1268    29.672291  83.714990  5.891196   66.484904      7
# 203     18.868056  15.658092  6.391174   88.510490      3
# 1303    24.746313  88.308663  6.581588   57.958261     21
# 365     18.810973  21.278330  5.889615  125.084915      9
# 1504    23.410447  91.699133  5.587906  116.077793      0
# 759     31.521047  66.557237  7.580527   61.711114      2
# 1450    27.465836  94.876790  6.440585   27.278998     15
# 641     29.830404  89.304283  6.324005   58.866871     14
# 615     29.784167  85.169070  6.793856   40.778728     14
# ----------------------------------
# 14
